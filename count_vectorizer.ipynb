# %%
from sklearn.feature_extraction.text import CountVectorizer

texts = [
    "vm crashed",
    "login issue",
    "vm kernel panic"
]

vectorizer = CountVectorizer()

vectorizer.fit(texts)

print(vectorizer.vocabulary_)
# Out:
# {'vm': 5, 'crashed': 0, 'login': 3, 'issue': 1, 'kernel': 2, 'panic': 4}
